# %%
# from replit import clear
#HINT: You can call clear() to clear the output in the console.
import os
from Art import logo
print(logo)
# os.system('cls')
bidder =input("What is your Name?:  ")
bid_amount = input("What is your bid?:$  ")
bidding_record={}
# check_other_bidders = input("Type 'yes' or 'no'.")


def check(check_other_bidders):
    if check_other_bidders == 'yes':
        return True
    else:
        return False


def bid_record(bidder,bid_amount):
    while check(check_other_bidders):
        bidder =input("What is your Name?:  ")
        bid_amount = input("What is your bid?:$  ")
        check_other_bidders = input("Type 'yes' or 'no'.")
        bidding_record[bidder]=bid_amount
        # os.system('cls')
    print("Highest bid is :---")
print(bidding_record)


bid_record(bidder,bid_amount)
# Out:
#                          ___________
#                          \         /
#                           )_______(
#                           |"""""""|_.-._,.---------.,_.-._
#                           |       | | |               | | ''-.
#                           |       |_| |_             _| |_..-'
#                           |_______| '-' `'---------'` '-'
#                           )"""""""(
#                          /_________\
#                        .-------------.
#                       /_______________\
#
# {}
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# p:\FRONTEND\GIT_main\My_Pythone_Notes_Collections\RAW\aNGeLaPy_uDeMy\Dr. Angela Yu\100 Days of Code The Complete Python Pro Bootcamp for 2023\D9\The Secret Auction Program Instructions,Code and Flow Chart\Auction.ipynb Cell 1 line 3
#      <a href='vscode-notebook-cell:/p%3A/FRONTEND/GIT_main/My_Pythone_Notes_Collections/RAW/aNGeLaPy_uDeMy/Dr.%20Angela%20Yu/100%20Days%20of%20Code%20The%20Complete%20Python%20Pro%20Bootcamp%20for%202023/D9/The%20Secret%20Auction%20Program%20Instructions%2CCode%20and%20Flow%20Chart/Auction.ipynb#W0sZmlsZQ%3D%3D?line=26'>27</a>     print("Highest bid is :---")
#      <a href='vscode-notebook-cell:/p%3A/FRONTEND/GIT_main/My_Pythone_Notes_Collections/RAW/aNGeLaPy_uDeMy/Dr.%20Angela%20Yu/100%20Days%20of%20Code%20The%20Complete%20Python%20Pro%20Bootcamp%20for%202023/D9/The%20Secret%20Auction%20Program%20Instructions%2CCode%20and%20Flow%20Chart/Auction.ipynb#W0sZmlsZQ%3D%3D?line=27'>28</a> print(bidding_record)
# ---> <a href='vscode-notebook-cell:/p%3A/FRONTEND/GIT_main/My_Pythone_Notes_Collections/RAW/aNGeLaPy_uDeMy/Dr.%20Angela%20Yu/100%20Days%20of%20Code%20The%20Complete%20Python%20Pro%20Bootcamp%20for%202023/D9/The%20Secret%20Auction%20Program%20Instructions%2CCode%20and%20Flow%20Chart/Auction.ipynb#W0sZmlsZQ%3D%3D?line=30'>31</a> bid_record(bidder,bid_amount)
#
# p:\FRONTEND\GIT_main\My_Pythone_Notes_Collections\RAW\aNGeLaPy_uDeMy\Dr. Angela Yu\100 Days of Code The Complete Python Pro Bootcamp for 2023\D9\The Secret Auction Program Instructions,Code and Flow Chart\Auction.ipynb Cell 1 line 2
#      <a href='vscode-notebook-cell:/p%3A/FRONTEND/GIT_main/My_Pythone_Notes_Collections/RAW/aNGeLaPy_uDeMy/Dr.%20Angela%20Yu/100%20Days%20of%20Code%20The%20Complete%20Python%20Pro%20Bootcamp%20for%202023/D9/The%20Secret%20Auction%20Program%20Instructions%2CCode%20and%20Flow%20Chart/Auction.ipynb#W0sZmlsZQ%3D%3D?line=19'>20</a> def bid_record(bidder,bid_amount):
# ---> <a href='vscode-notebook-cell:/p%3A/FRONTEND/GIT_main/My_Pythone_Notes_Collections/RAW/aNGeLaPy_uDeMy/Dr.%20Angela%20Yu/100%20Days%20of%20Code%20The%20Complete%20Python%20Pro%20Bootcamp%20for%202023/D9/The%20Secret%20Auction%20Program%20Instructions%2CCode%20and%20Flow%20Chart/Auction.ipynb#W0sZmlsZQ%3D%3D?line=20'>21</a>     while check(check_other_bidders):
#      <a href='vscode-notebook-cell:/p%3A/FRONTEND/GIT_main/My_Pythone_Notes_Collections/RAW/aNGeLaPy_uDeMy/Dr.%20Angela%20Yu/100%20Days%20of%20Code%20The%20Complete%20Python%20Pro%20Bootcamp%20for%202023/D9/The%20Secret%20Auction%20Program%20Instructions%2CCode%20and%20Flow%20Chart/Auction.ipynb#W0sZmlsZQ%3D%3D?line=21'>22</a>         bidder =input("What is your Name?:  ")
#      <a href='vscode-notebook-cell:/p%3A/FRONTEND/GIT_main/My_Pythone_Notes_Collections/RAW/aNGeLaPy_uDeMy/Dr.%20Angela%20Yu/100%20Days%20of%20Code%20The%20Complete%20Python%20Pro%20Bootcamp%20for%202023/D9/The%20Secret%20Auction%20Program%20Instructions%2CCode%20and%20Flow%20Chart/Auction.ipynb#W0sZmlsZQ%3D%3D?line=22'>23</a>         bid_amount = input("What is your bid?:$  ")
#
# UnboundLocalError: local variable 'check_other_bidders' referenced before assignment

# %%
import os
from Art import logo

print(logo)
bidder = input("What is your Name?: ")
bid_amount = input("What is your bid?: $")
bidding_record = {}


def check(check_other_bidders):
    if check_other_bidders == 'yes':
        return True
    else:
        return False


def bid_record(bidder, bid_amount):
    check_other_bidders = input("Type 'yes' or 'no': ")
    while check(check_other_bidders):
        bidder = input("What is your Name?: ")
        bid_amount = input("What is your bid?: $")
        check_other_bidders = input("Type 'yes' or 'no': ")
        bidding_record[bidder] = bid_amount
        print(bidding_record)
    print("Highest bid is :---")
# Out:
#                          ___________
#                          \         /
#                           )_______(
#                           |"""""""|_.-._,.---------.,_.-._
#                           |       | | |               | | ''-.
#                           |       |_| |_             _| |_..-'
#                           |_______| '-' `'---------'` '-'
#                           )"""""""(
#                          /_________\
#                        .-------------.
#                       /_______________\

# %%
import os
from Art import logo

print(logo)


def check(check_other_bidders):
    if check_other_bidders == 'yes':
        return True
    else:
        return False


def bid_record():
    bidder = input("What is your Name?: ")
    bid_amount = float(input("What is your bid?: $"))
    bidding_record = {bidder: bid_amount}
    check_other_bidders = input("Type 'yes' or 'no': ")
    while check(check_other_bidders):
        bidder = input("What is your Name?: ")
        bid_amount = float(input("What is your bid?: $"))
        bidding_record[bidder] = bid_amount
        check_other_bidders = input("Type 'yes' or 'no': ")
    print("Bidding record:", bidding_record)
    highest_bidder = max(bidding_record, key=lambda x: bidding_record[x])
    highest_bid = bidding_record[highest_bidder]
    print("Highest bidder:", highest_bidder)
    print("Highest bid:", highest_bid)


bid_record()
# Out:
#                          ___________
#                          \         /
#                           )_______(
#                           |"""""""|_.-._,.---------.,_.-._
#                           |       | | |               | | ''-.
#                           |       |_| |_             _| |_..-'
#                           |_______| '-' `'---------'` '-'
#                           )"""""""(
#                          /_________\
#                        .-------------.
#                       /_______________\
#
# Bidding record: {'as': 12.0, 'bg': 56.0}
# Highest bidder: bg
# Highest bid: 56.0

# %%
import os
from Art import logo

print(logo)


def check(check_other_bidders):
    if check_other_bidders == 'yes':
        return True
    else:
        return False


def bid_record():
    bidder = input("What is your Name?: ")
    bid_amount = float(input("What is your bid?: $"))
    bidding_record = {bidder: bid_amount}
    check_other_bidders = input("Type 'yes' or 'no': ")
    while check(check_other_bidders):
        bidder = input("What is your Name?: ")
        bid_amount = float(input("What is your bid?: $"))
        bidding_record[bidder] = bid_amount
        check_other_bidders = input("Type 'yes' or 'no': ")
    print("Bidding record:", bidding_record)
    highest_bidder = max(bidding_record, key=lambda x: bidding_record[x])
    highest_bid = bidding_record[highest_bidder]
    print("Highest bidder:", highest_bidder)
    print("Highest bid:", highest_bid)

# %%
import os
from Art import logo

print(logo)


def check(check_other_bidders):
    if check_other_bidders.lower() == 'yes':
        return True
    else:
        return False


def bid_record():
    bidding_record = {}  # Empty dictionary to store the bidders and their bids

    # bidder = input("What is your Name?: ")
    # bid_amount = float(input("What is your bid?: $"))
    # bidding_record[bidder] = bid_amount  # Add the first bidder and their bid to the record

    check_other_bidders = input("Type 'yes' if there are other bidders, or 'no' to finish: ")
    while check(check_other_bidders):
        bidder = input("What is your Name?: ")
        bid_amount = float(input("What is your bid?: $"))
        bidding_record[bidder] = bid_amount  # Add the bidder and their bid to the record
        check_other_bidders = input("Type 'yes' if there are other bidders, or 'no' to finish: ")
        os.system('clear')  # Clears the screen before taking the second bid

    # print("Bidding record:", bidding_record)

    highest_bidder = ''
    highest_bid = 0

    # Find the highest bidder and their bid in the record
    for bidder, bid in bidding_record.items():
        if bid > highest_bid:
            highest_bidder = bidder
            highest_bid = bid

    print("Highest bidder:", highest_bidder)
    print("Highest bid:", highest_bid)


bid_record()
